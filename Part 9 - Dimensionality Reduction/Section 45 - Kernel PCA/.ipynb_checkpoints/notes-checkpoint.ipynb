# %% [raw]
# Even though you apply kernal PCA to linear model , Kernal PCA will be able to extract new components

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# kernel trick(using different dimensions) + PCA --> kernel PCA

# %% [raw]
# you can use KPCA,when u didn't get proper results in PCA, might be problem in linearity

# %% [markdown]
# ![image.png](attachment:image.png)
