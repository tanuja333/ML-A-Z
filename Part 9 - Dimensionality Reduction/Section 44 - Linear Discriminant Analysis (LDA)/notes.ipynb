# %% [markdown]
# # LDA -> Linear discriminent analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://sebastianraschka.com/Articles/2014_python_lda.html

# %% [raw]
# 1. LDA is supervide , as it selects based on the dependent variable
# 2. PCA is implemented unsupervised because it is applied without taking dependent variable (y) into consideration

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
