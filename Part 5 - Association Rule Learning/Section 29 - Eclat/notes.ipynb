# %% [markdown]
# # Intution of ECLAT

# %% [raw]
# Simplified version of Apriori
# Here we talk about sets
# In eclat model we only have support
# here we look at set of items occur -> ex ., set of movies

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# M -> set of 2 movies or more -> how often does the watchers like these 2 movies together

# %% [markdown]
# ![image.png](attachment:image.png)
