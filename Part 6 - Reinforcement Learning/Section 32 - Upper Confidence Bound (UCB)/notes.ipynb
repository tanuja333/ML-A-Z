# %% [raw]
# The Multi armed bandit problem - UBC -> upper confidence bound
# reward--> +1
# punishment --> 0
# reinforcement

# %% [raw]
# should choose a best distribution side
# ex can go with coca cola advertisement

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# to know best advertisement - 1 optio A/B test -> will take time and they are just for exploration
# but here -> find out best in quickest way and start to explore along the path

# %% [markdown]
# # Upper confidence bound intution

# %% [raw]
# Multi arm bandit problem is similar to finding out whcih advertisement is best among 500 adds you have

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Upper bounds.
# initial value -> exploration is done -red dots.
# then from that level we calculate the max and min bound regions in between the bounds where expected value is present.
# this leaves us to test the expected value - colours

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Reinforcement learning is also called as online learning or interactive learning -> dynamic

# %% [markdown]
# # Implementation of upper confidence bound algorithm

# %% [raw]
# Same algm as pasted above
# as we see by coding that between UCB and random sampling , we will get more rewards using UBC
