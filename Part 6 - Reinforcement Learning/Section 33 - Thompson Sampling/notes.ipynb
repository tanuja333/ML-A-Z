# %% [markdown]
# # Thompson sampling for bandit problem

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Thompson sampling is probablistic approach

# %% [markdown]
# ## comparision b/w thompson and UCB

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# From executing the probabilistic Thompson sampling -> it gives as more rewards than UBC
