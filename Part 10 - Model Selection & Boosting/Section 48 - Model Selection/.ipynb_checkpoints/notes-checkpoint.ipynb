# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# K fold cross validation is used for evaluation of models performance

# %% [raw]
# Grid search is used for imroving model performance -> uses tuning of hyper parameters
